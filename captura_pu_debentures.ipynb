# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/royopa/1001/blob/master/captura_pu_debentures.ipynb)

# %% [markdown]
# # Instalando dependências do Projeto
# ---

# %%
# !pip install -q pandas
# !pip install -q tqdm
# !pip install -q requests
# !pip install -q xlrd
# !pip install -q requests-html
# !pip install -q wget
# !pip install -q bizdays
# !pip install -q bs4

# %% [markdown]
# # Pega todas as debêntures registradas para geração da URL de download
# ---

# %%
import requests
from bs4 import BeautifulSoup
import os
import wget

url_base = 'http://www.debentures.com.br/exploreosnd/consultaadados/emissoesdedebentures/'
url = url_base+'puhistorico_f.asp'
res = requests.get(url)

while res.status_code != 200:
  res = requests.get(url)

soup = BeautifulSoup(res.text,"html.parser")
select = soup.find("select", {"name":"ativo"})

urls = []
for option in select.find_all('option'):
    ativo = option['value'].strip()
    
    if len(ativo) < 6:
      continue
    
    url_download = url_base + 'puhistorico_e.asp?op_exc=False&dt_ini=&dt_fim=&Submit.x=34&Submit.y=13&ativo='+ativo+'++++'
    urls.append({'ativo': ativo,'url':url_download})

# %% [markdown]
# # Após pegar todos os links, inicia o download da página
# ---

# %%
directory = 'downloads'
if not os.path.exists(directory):
    os.makedirs(directory)
        
for url in urls:
    print('Baixando arquivo do ativo', url['ativo'])
    name_file = url['ativo']+'.csv'
    print(name_file)
    path_file = os.path.join('downloads', name_file)
    if not os.path.exists(path_file):
        wget.download(url['url'], path_file)
# Out:
# Baixando arquivo do ativo AALR11
# AALR11.csv
# Baixando arquivo do ativo AALR21
# AALR21.csv
# Baixando arquivo do ativo AARJ11
# AARJ11.csv
# Baixando arquivo do ativo ABEV11
# ABEV11.csv
# Baixando arquivo do ativo ABPR11
# ABPR11.csv
# Baixando arquivo do ativo ABPR21
# ABPR21.csv
# Baixando arquivo do ativo ACEF11
# ACEF11.csv
# Baixando arquivo do ativo ACEF12
# ACEF12.csv
# Baixando arquivo do ativo ADMA12
# ADMA12.csv
# Baixando arquivo do ativo AEGE12
# AEGE12.csv
# Baixando arquivo do ativo AEPS16
# AEPS16.csv
# Baixando arquivo do ativo AEPS17
# AEPS17.csv
# Baixando arquivo do ativo AESL14
# AESL14.csv
# Baixando arquivo do ativo AESL16
# AESL16.csv
# Baixando arquivo do ativo AESL17
# AESL17.csv
# Baixando arquivo do ativo AGCM11
# AGCM11.csv
# Baixando arquivo do ativo AGEO12
# AGEO12.csv
# Baixando arquivo do ativo AGEO13
# AGEO13.csv
# Baixando arquivo do ativo AGFO11
# AGFO11.csv
# Baixando arquivo do ativo AGGU13
# AGGU13.csv
# Baixando arquivo do ativo AGND11
# ...
